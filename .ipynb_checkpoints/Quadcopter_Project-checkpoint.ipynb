# %% [markdown]
# # Project: Train a Quadcopter How to Fly
#
# I leave only the cells where I have to put something. I remove all the parts that are not relevant to clear the notebook.

# %% [markdown]
# ## Notes
#
# In the introduction there is the following statement:
# - `physics_sim.py`: This file contains the simulator for the quadcopter.  **DO NOT MODIFY THIS FILE**.
#
# About this point, I had to modify some lines in this file. I explained this in the quadcopter beta slack channel, which has recently been archived.
#
# As you can see in my code, I modified the reset function, since before it was not using the copy.copy() function to give the initial values on each episode, and therefore those initial values where the same variables in memory as the ones changing and the reset had no effect (speed and others were maintained between episodes).
#
# I removed the angle wrapping:
# #angles = (angles + 2 * np.pi) % (2 * np.pi)
# As in a physical simulation, I cannot understand the point of the angle jumping a full turn all the time.
#
# These and other questions I posted in the mentors slack with no response and finally in the general forum, with the same success:
# https://discussions.udacity.com/t/some-doubts-about-the-version-2-of-the-project/637475
#
# For this reason I have not been able to make the system learn. I have tried to different approaches, this one based on the code provided by udacity, and a second one adapting an implementation of the Deep Deterministic Policy Gradients I found online:
# https://github.com/rpicatoste/dlndf-project5-drl-quadcopter-2
#
# I believe after using this second version of code implementing DDPG that the problem is not in the DDPG algorithm, but either in the hyperparameters that I used, or in problems using the simulator, which as I explain in the forum post, I have not managed to understand.

# %% [markdown]
# ## The Task
#
# For the task, I have been in the simplest ones, which are starting and finishing in (0,0,10); and starting in (0,0,5) and finishing in (0,0,10).
#
# Since I could not learn properly, I did not go further.

# %% [markdown]
# ## The implementation
#
# The actor, the critic and the agent for this attempt if based on the code provided by the project lesson in the classroom. There is a file for each class: actor, critic, agent and task.
#
# To run the code you can run from console: *python main.py* or the cell below.

# %%
import main
# Out:
# Using TensorFlow backend.
# Start training...
#
# Running test episode ...
# state [ 0.  0.  5.  0.  0.  0.  0.  0.  5.  0.  0.  0.  0.  0.  5.  0.  0.  0.]
# state.shape (18,)
# Finished test episode!
#
# Episode: 200 (stuck:    0), score: -1217.0, reward: -20688.20, noise(sigma:  0.608, theta:  0.273, state,  405.3, 405.1, 405.2, 404.6)(action: 780.1, 458.7, 465.4, 460.3))
# Running test episode ...
# state [ 0.  0.  5.  0.  0.  0.  0.  0.  5.  0.  0.  0.  0.  0.  5.  0.  0.  0.]
# state.shape (18,)
# Finished test episode!
#
# Episode: 351 (stuck:    0), score:  -534.1, reward: -6943.06, noise(sigma:  0.416, theta:  0.187, state,  405.2, 405.7, 406.8, 405.5)(action: 475.0, 455.7, 455.6, 455.6))
# Running test episode ...
# state [ 0.  0.  5.  0.  0.  0.  0.  0.  5.  0.  0.  0.  0.  0.  5.  0.  0.  0.]
# state.shape (18,)
# Finished test episode!
#
# ...

# %% [markdown]
# ## Plot the results
#
# Below I paste the results that were somehow remarkable, even if the goal was not achieved.
# ![](figures_to_keep\learning_1.png)
# ![](figures_to_keep\learning_2.png)
# ![](figures_to_keep\learning_3.png)
#
# These figures show how the agent tries to learn to get a better reward, but it never gets good enough.

# %% [markdown]
# ## Reflections
#
# **Question 1**: Describe the task that you specified in `task.py`.  How did you design the reward function?
#
# **Answer**:
# The task as commented above was simply to start at (0,0,5) and go up to (0,0,10). In the figure below it is shown how the agent perform the task after training. It goes up (3D image bottom right), but passes the goal and continues.
#
# The different rewards are plot to check that no one is making the others be neglected:
#  - Surviving is a +1 for staying alive each time step.
#  - Distance is the euclidean distance to the goal respect to the current position.
#  - Angles is a penalization to angles going far from 0. I added this trying to facilitate the task of just going up a bit, but it did not help.
#  - Angular speed is similar, I penalize the angular speed as we want just to go up.
#
# ![](figures_to_keep\going_up.png)

# %% [markdown]
# **Question 2**: Discuss your agent briefly, using the following questions as a guide:
#
# - What learning algorithm(s) did you try? What worked best for you?
# - What was your final choice of hyperparameters (such as $\alpha$, $\gamma$, $\epsilon$, etc.)?
# - What neural network architecture did you use (if any)? Specify layers, sizes, activation functions, etc.
#
# **Answer**:
#
# I tried the Deep Deterministic Policy Gradients, with 2 different implementations adapted to the task at hand.
#
# For hyperparameters, I tried many different ones, centered in the ones pasted below from the code:
#     #%% Parameters
#     exploration_mu = 405
#     exploration_theta = 0.15*3
#     exploration_sigma = 0.2*5
#     buffer_size = 100000
#     batch_size = 64
#     gamma = 0.99
#     tau = 0.01
#     actor_learning_rate = 0.0001*0.10
#     critic_learning_rate = 0.001*0.10
#
# These come from different places: the DDPG paper and in the implementations found on the internet.

# %% [markdown]
# **Question 3**: Using the episode rewards plot, discuss how the agent learned over time.
#
# - Was it an easy task to learn or hard?
# - Was there a gradual learning curve, or an aha moment?
# - How good was the final performance of the agent? (e.g. mean rewards over the last 10 episodes)
#
# **Answer**:
#
# I tried to find an easy task without success. I tried forcing the proper control actions from time to time so the agent could see them.
#
# No aha moment so far...
#
# Not good, the task is not accomplished.

# %% [markdown]
# **Question 4**: Briefly summarize your experience working on this project. You can use the following prompts for ideas.
#
# - What was the hardest part of the project? (e.g. getting started, plotting, specifying the task, etc.)
# - Did you find anything interesting in how the quadcopter or your agent behaved?
#
# **Answer**:
#
# This time the course in udacity gives not very good clues on what to do. Normally there are important similar steps practiced during the lessons, but not this time.
#
# I could not get any reply in the mentors slack or in the forum, but the deadline to present this project and become reviewer has arrived, so I send what I have with the hope of getting some clue on what should be done to make this work. It probably is too late to get the certificaiton and be able to continue as mentor, but if there is any chance, I would like it.
